# %%
import os 
current = os.getcwd()
print(current)
# Out:
# c:\Users\saura\OneDrive\Desktop\testing\genai\06_File_Handling

# %%
#create a new directory 

new_directory = 'package'
os.mkdir(new_directory)
print(f'new directory: {new_directory}')
# Out:
# new directory: package

# %%
# list all files and directories

files_and_directories = os.listdir('.')
print(f'files and directories in current directory: { files_and_directories}')
# Out:
# files and directories in current directory: ['destination.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'filepath.ipynb', 'package', 'source.txt']

# %%
## joining paths

dir_name = 'folder'
file_name = 'file.txt'

full_path = os.path.join(dir_name, file_name)
print(f'full path: {full_path}')
# Out:
# full path: folder\file.txt

# %%
path = 'exaple.txt'

if os.path.exists(path):
    print(f'{path} exists')
else:
    print(f'{path} does not exist')
# Out:
# exaple.txt does not exist

# %%
# checking if current path is file or a directory 

path = 'example.txt'

if os.path.isfile(path):
    print(f'{path} is a file')
elif os.path.isdir(path):
    print(f'{path} is a directory')
else:
    print(f'{path} does not exist')
# Out:
# example.txt is a file

# %%
## getting absolute path 

relative_path = 'example.txt'
absolute_path = os.path.abspath(relative_path)
print(f'absolute path: {absolute_path}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       1 ## getting absolute path
#       2
#       3 relative_path = 'example.txt'
# ----> 4 absolute_path = os.abspath(relative_path)
#       5 print(f'absolute path: {absolute_path}')
#
# AttributeError: module 'os' has no attribute 'abspath'

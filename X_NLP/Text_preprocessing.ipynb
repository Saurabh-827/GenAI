# %%
## Text Preprocessing 
## two types - basic and advance 

## basic text preprocessing
# lowercasing - using .lower()
# Removing html tags - using regex( regular expression)
# Remove urls - using regex
# Removing punctuation - using string.punctuation
# chat word treatment - using a dictionary of chat words and their expansions
# Spelling correction - using libraries like TextBlob or pyspellchecker
# Removing stop words - using libraries like NLTK or spaCy
# Handling Emojis - using libraries like emoji or regex to identify and remove emojis
# Tokenization - Tokenization is the process of breaking down text into smaller units, 
                 # such as words or sentences. 
                 # This can be done using libraries like NLTK, spaCy(good from nltk), or the built-in split() method in Python.

## Stemming - Stemming is the process of reducing words (inflected words) to their root form.
                # It involves removing suffixes from words to get to the base word.
                # Libraries like NLTK provide stemmers like PorterStemmer or SnowballStemmer.
## Lemmatization - Lemmatization is similar to stemming but aims to reduce words to their base or dictionary form (lemma).
                  # It considers the context and meaning of words.
                  # Libraries like NLTK or spaCy provide lemmatizers.

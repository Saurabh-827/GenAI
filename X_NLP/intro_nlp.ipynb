# %%
# Introduction OF NLP
# What is NLP?
# Need of NLP
# Real World Applications 
# Common NLP Tasks
# Approaches to NLP

##  what is the nlp ?

# Natural Language Processing (NLP) is a subfield of linguistics, computer science, and artificial intelligence
# concerned with the interactions between computers and human language,
# in particular how to program computers to process and analyze large amounts of natural language data.
# Jo natural language processing h isme hum humans ki nautral way of communication ko process karne ki kosis krte h by using systems.



## Real World Applications 

# 1- Contextual Advertisements 
# 2- Email clients- Spam Filtering, smart reply
# 3- Social Media -  removing adult content,  opinion mining
# 4- Healthcare - Medical Transcription, Drug Discovery
# 5- Customer Service - Chatbots, Virtual Assistants


## Common NLP tasks
# Text/Document Classification - Assigning predefined categories to text documents based on their content. For example, classifying emails as spam or not spam.
# Sentiment Analysis
# Information retrieval
# Parts of speech tagging 
# Language detection and translation
# Conversational Agents
# Knowledge Graph and QA systems 
# Text Summarization
# Topic Modeling 
# Text Generation 
# Spell Checking and grammar correction


## Approaches to NLP 
# Heuristic Methods - Heuristic Approaches are smart shortcuts.  Examples - Regular expressions, Wordnet etc
# Machine Learning Based Methods -  Examples - SVM, Naive Bayes, Maximum Entropy Classifiers etc
# Deep Learning Based Methods - Examples - Recurrent Neural Networks (RNNs), Convolutional Neural Networks (CNNs), Transformers etc

## Challenges in NLP 
# Ambiguity - Words with multiple meanings (e.g., "bank" can mean a financial institution or the side of a river).
# Context Understanding - Understanding the context of a sentence or conversation can be difficult for NLP systems.
# Sarcasm and Irony Detection - Detecting sarcasm and irony in text can be challenging for NLP systems.
# Colloquialisms and slang - Understanding and processing colloquial language and slang can be difficult for NLP systems.
